# %% [markdown]
# ## Read csv and Table server to online

# %%
import pandas as pa

# %%
s=pa.read_csv("income.csv")
s
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 0  04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657  62993  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528

# %%
s['2005']
# Out:
# 0    37150
# 1    55891
# 2    45245
# 3    36658
# 4    51755
# Name: 2005, dtype: int64

# %%
s['2006'][2]
# Out:
# 46657

# %%
s.iloc[2,3]
# Out:
# 46657

# %%
s.iloc[:1:3]
# Out:
#        GEOID    State   2005   2006   2007   2008   2009   2010   2011   2012  \
# 0  04000US01  Alabama  37150  37952  42212  44476  39980  40933  42590  43464
#
#     2013
# 0  41381

# %%
s.iloc[0:1,2:10]
# Out:
#     2005   2006   2007   2008   2009   2010   2011   2012
# 0  37150  37952  42212  44476  39980  40933  42590  43464

# %%
s.iloc[:,2:]
# Out:
#     2005   2006   2007   2008   2009   2010   2011   2012   2013
# 0  37150  37952  42212  44476  39980  40933  42590  43464  41381
# 1  55891  56418  62993  63989  61604  57848  57431  63648  61137
# 2  45245  46657  62993  46914  45739  46896  48621  47044  50602
# 3  36658  37057  40795  39586  36538  38587  41302  39018  39919
# 4  51755  55319  55734  57014  56134  54283  53367  57020  57528

# %%
s.iloc[:,2].mean()
# Out:
# 45339.8

# %%
s.iloc[:,2].prod()
# Out:
# 2304332586102593708

# %%
s.iloc[:,2]
# Out:
# 0    37150
# 1    55891
# 2    45245
# 3    36658
# 4    51755
# Name: 2005, dtype: int64

# %%
s.iloc[:,2].sum()
# Out:
# 226699

# %%
s.iloc[:,[2,5,7]].sum()
# Out:
# 2005    226699
# 2008    251979
# 2010    238547
# dtype: int64

# %%
s.iloc[:2].min()
# Out:
# GEOID    04000US01
# State      Alabama
# 2005         37150
# 2006         37952
# 2007         42212
# 2008         44476
# 2009         39980
# 2010         40933
# 2011         42590
# 2012         43464
# 2013         41381
# dtype: object

# %%
s.iloc[:2].max()
# Out:
# GEOID    04000US02
# State       Alaska
# 2005         55891
# 2006         56418
# 2007         62993
# 2008         63989
# 2009         61604
# 2010         57848
# 2011         57431
# 2012         63648
# 2013         61137
# dtype: object

# %%
s
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 0  04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657  62993  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528

# %%
s.iloc[2]
# Out:
# '04000US04'

# %%
s.iloc[2,1]
# Out:
# 'Arizona'

# %%
s.loc[(s['2006']>50000)&(s['2006']<60000)]
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 1  63648  61137
# 4  57020  57528

# %%
s.iloc[2,1]
# Out:
# 'Arizona'

# %%
s.loc[(s['2009']>50000)&(s['2010']<60000)]
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 1  63648  61137
# 4  57020  57528

# %%
s['2006'][2]=20198
# Out:
# C:\Programfiles\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
s["2006"]
# Out:
# 0    37952
# 1    56418
# 2    20198
# 3    37057
# 4    55319
# Name: 2006, dtype: int64

# %%
s
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 0  04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  20198  62993  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528

# %%
t=pa.read_csv("http://bit.ly/imdbratings")
t
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
t.shape
# Out:
# (979, 6)

# %%
t.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
t.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
t.tail()
# Out:
#      star_rating                                            title  \
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 974             PG     Comedy       116
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 977             PG     Horror       114
# 978              R      Crime       126
#
#                                            actors_list
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# ...

# %%
t.sort_values(by="star_rating",axis=0,ascending=False)
t.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
t.loc[t['genre']=='comedy']
# Out:
# Empty DataFrame
# Columns: [star_rating, title, content_rating, genre, duration, actors_list]
# Index: []

# %%
p=pa.read_table("http://bit.ly/chiporders")
p
# Out:
# C:\Programfiles\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """Entry point for launching an IPython kernel.
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# ...
